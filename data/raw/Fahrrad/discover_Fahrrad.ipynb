# %%
import pandas as pd

df_standorte = pd.read_excel('gesamtdatei-stundenwerte.xlsx', sheet_name = 'Standortdaten')
df_standorte.head()
# Out:
#     Zählstelle Beschreibung - Fahrtrichtung  Breitengrad  Längengrad  \
# 0    12-PA-SCH               Schwedter Steg    52.549071   13.400367
# 1  02-MI-JAN-N         Jannowitzbrücke Nord    52.513932   13.417835
# 2  02-MI-JAN-S          Jannowitzbrücke Süd    52.513943   13.417611
# 3    13-CW-PRI          Prinzregentenstraße    52.488136   13.333120
# 4  18-TS-YOR-O              Yorckstraße Ost    52.491938   13.373472
#
#   Installationsdatum
# 0         2012-03-01
# 1         2015-04-01
# 2         2015-04-01
# 3         2015-04-01
# 4         2015-04-01

# %%
df_2018 = pd.read_excel('gesamtdatei-stundenwerte.xlsx', sheet_name = 'Jahresdatei 2018')
df_2018.head()
# Out:
#   Zählstelle        Inbetriebnahme  02-MI-JAN-N 01.04.2015  \
# 0              2018-01-01 00:00:00                      12
# 1              2018-01-01 01:00:00                      17
# 2              2018-01-01 02:00:00                      25
# 3              2018-01-01 03:00:00                      18
# 4              2018-01-01 04:00:00                      15
#
#    02-MI-JAN-S 01.04.2015  03-MI-SAN-O 01.06.2015  03-MI-SAN-W 01.06.2015  \
# 0                       9                      15                       1
# 1                      16                       7                       7
# 2                      18                       5                      12
# 3                      19                       8                      13
# 4                      12                       6                       3
#
#    05-FK-OBB-O 01.06.2015  05-FK-OBB-W 01.06.2015  06-FK-FRA-O 01.06.2016  \
# 0                      11                      18                     3.0
# ...

# %%
df_2018.isnull().sum()

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 27 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Zählstelle        Inbetriebnahme  8760 non-null   datetime64[ns]
#  1   02-MI-JAN-N 01.04.2015            8760 non-null   int64
#  2   02-MI-JAN-S 01.04.2015            8760 non-null   int64
#  3   03-MI-SAN-O 01.06.2015            8760 non-null   int64
#  4   03-MI-SAN-W 01.06.2015            8760 non-null   int64
#  5   05-FK-OBB-O 01.06.2015            8760 non-null   int64
#  6   05-FK-OBB-W 01.06.2015            8760 non-null   int64
#  7   06-FK-FRA-O 01.06.2016            8751 non-null   float64
#  8   06-FK-FRA-W 01.06.2016            8760 non-null   int64
#  9   10-PA-BER-N 01.05.2016            8760 non-null   int64
#  10  10-PA-BER-S 01.05.2016            8759 non-null   float64
# ...

# %%
#ersetzen die null Werte mit 0 
# überprüfen ob wir können erstzen die 0 werte mit einen durschnitt vom letzten Jahr in der selben Jahr/Monat/Stunde und Zähler
# hinzufügen andere Spalte mit dem nich vorhandene Zähler
# hinzufügen die Zeile Jahre 2019 .. to Dataframe 2018 und soweiter von Jedes Sheet
# Update die Name von Columns nur lassen der Name von Zähler ohne Datum
# check pro Farbe ob die reconstruite Daten gut  sind vllt muss ich doch anpassen

#csv Datei erstellen für alle Autos in jedes Jahr
